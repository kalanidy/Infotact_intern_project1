# %% [markdown]
# # Multi-Touch Marketing Attribution & ROI Dashboard
#
# ## Week 1 - Day 1
#
# ### Objective
#
# Create the project data dictionary and understand the structure of all datasets before beginning preprocessing.
#
# ---
#
# ## Dataset Files
#
# This project uses five relational datasets:
#
# - customers.csv
# - campaigns.csv
# - events.csv
# - products.csv
# - transactions.csv
#
# Together they represent the complete customer marketing journey from campaign exposure to purchase.

# %% [markdown]
# # Data Dictionary
#
# ## customers.csv
#
# | Column | Description |
# |---------|-------------|
# | customer_id | Unique customer identifier |
# | first_name | Customer first name |
# | last_name | Customer last name |
# | gender | Customer gender |
# | age | Customer age |
# | country | Customer country |
# | city | Customer city |
# | signup_date | Registration date |
# | loyalty_tier | Customer loyalty level |
#
# ---
#
# ## campaigns.csv
#
# | Column | Description |
# |---------|-------------|
# | campaign_id | Campaign identifier |
# | campaign_name | Campaign name |
# | channel | Marketing channel |
# | campaign_type | Email, Social, Search etc. |
# | start_date | Campaign start |
# | end_date | Campaign end |
#
# ---
#
# ## events.csv
#
# | Column | Description |
# |---------|-------------|
# | event_id | Event identifier |
# | customer_id | Customer |
# | session_id | Session |
# | timestamp | Event time |
# | event_type | View, Click, Purchase etc. |
# | campaign_id | Campaign involved |
# | product_id | Product |
# | device_type | Mobile/Desktop |
# | traffic_source | Organic/Paid |
#
# ---
#
# ## products.csv
#
# | Column | Description |
# |---------|-------------|
# | product_id | Product identifier |
# | product_name | Product |
# | category | Category |
# | brand | Brand |
# | price | Selling price |
#
# ---
#
# ## transactions.csv
#
# | Column | Description |
# |---------|-------------|
# | transaction_id | Purchase ID |
# | customer_id | Customer |
# | campaign_id | Campaign |
# | product_id | Product |
# | quantity | Quantity sold |
# | revenue | Revenue |
# | purchase_date | Purchase date |

# %% [markdown]
# # Week 1 - Day 1 GitHub Issues
#
# ## Project: Multi-Touch Marketing Attribution & ROI Dashboard
#
# ---
#
# # Issue 1: Create Data Dictionary
#
# ## Title
# Create Data Dictionary for Marketing Attribution Dataset
#
# ## Description
#
# ### Objective
# Create a comprehensive data dictionary for all five datasets used in the project.
#
# ### Tasks
# - Review all CSV files
# - Identify all columns
# - Document data types
# - Describe each attribute
# - Explain the purpose of every dataset
#
# ### Files
# - customers.csv
# - campaigns.csv
# - events.csv
# - products.csv
# - transactions.csv
#
# ### Deliverable
# A Markdown document containing the complete data dictionary.
#
# ### Labels
# - documentation
# - week-1
# - data-analysis
#
# ### Priority
# High
#
# ---
#
# # Issue 2: Acquire and Load Raw Dataset
#
# ## Title
# Load Raw Marketing Dataset into Pandas Notebook
#
# ## Description
#
# ### Objective
# Load all raw datasets into a Jupyter Notebook for analysis.
#
# ### Tasks
# - Import Pandas
# - Load customers.csv
# - Load campaigns.csv
# - Load events.csv
# - Load products.csv
# - Load transactions.csv
#
# ### Validation
# - Verify datasets load successfully
# - Display first five records
# - Check dataset dimensions
#
# ### Deliverable
# Jupyter Notebook with all datasets successfully loaded.
#
# ### Labels
# - python
# - week-1
#
# ### Priority
# High
#
# ---
#
# # Issue 3: Perform Initial Dataset Inspection
#
# ## Title
# Inspect Dataset Structure and Quality
#
# ## Description
#
# ### Objective
# Understand the structure of each dataset before cleaning.
#
# ### Tasks
# - Check row counts
# - Check column counts
# - Inspect data types
# - View sample records
# - Generate dataset information
#
# ### Deliverable
# Initial data inspection notebook.
#
# ### Labels
# - python
# - data-analysis
#
# ### Priority
# High
#
# ---
#
# # Issue 4: Create Dataset Relationship Mapping
#
# ## Title
# Design Dataset Relationship Mapping
#
# ## Description
#
# ### Objective
# Identify relationships between all datasets for Power BI data modeling.
#
# ### Tasks
# - Identify primary keys
# - Identify foreign keys
# - Create relationship diagram
# - Verify one-to-many relationships
#
# ### Expected Relationships
# - Customers → Events
# - Customers → Transactions
# - Campaigns → Events
# - Campaigns → Transactions
# - Products → Events
# - Products → Transactions
#
# ### Deliverable
# Entity Relationship (ER) Diagram.
#
# ### Labels
# - documentation
# - powerbi
#
# ### Priority
# Medium
#
# ---
#
# # Issue 5: Prepare CRM Conversion Dataset
#
# ## Title
# Prepare CRM Conversion Dataset
#
# ## Description
#
# ### Objective
# Identify customer conversion events from the marketing datasets.
#
# ### Tasks
# - Review customer journeys
# - Match events with transactions
# - Identify conversion events
# - Verify campaign mapping
#
# ### Deliverable
# Base conversion dataset ready for preprocessing.
#
# ### Labels
# - data-analysis
# - python
#
# ### Priority
# Medium
#
# ---
#
# # Issue 6: Verify Dataset Integrity
#
# ## Title
# Verify Dataset Integrity Before Cleaning
#
# ## Description
#
# ### Objective
# Ensure datasets are suitable for preprocessing.
#
# ### Tasks
# - Check missing values
# - Identify duplicate records
# - Verify unique IDs
# - Validate dataset consistency
#
# ### Deliverable
# Dataset validation report.
#
# ### Labels
# - python
# - validation
#
# ### Priority
# High
#
# ---
#
# # Issue 7: Set Up Week 1 Project Board
#
# ## Title
# Set Up Week 1 Kanban Board
#
# ## Description
#
# ### Objective
# Organize Week 1 tasks using GitHub Projects.
#
# ### Columns
# - To Do
# - In Progress
# - Review
# - Done
#
# ### Tasks
# - Add all Week 1 issues
# - Assign labels
# - Set priorities
# - Track progress
#
# ### Deliverable
# GitHub Project Board with all Week 1 issues.
#
# ### Labels
# - github
# - project-management
#
# ### Priority
# Low

# %% [markdown]
# # Week 1 - Day 2
#
# # Data Acquisition and Dataset Loading
#
# ## Objective
#
# The objective of Day 2 is to acquire the raw CRM conversion datasets and load them into a Pandas notebook for initial exploration.
#
# ### Datasets Used
#
# - customers.csv
# - campaigns.csv
# - events.csv
# - products.csv
# - transactions.csv
#
# These datasets together represent the complete customer journey from marketing interactions to purchases.

# %%
# Import required libraries

import pandas as pd
import numpy as np


pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 10)

# %%
customers = pd.read_csv(r"A:\Multi-Touch Marketing Attribution\customers.csv")
campaigns = pd.read_csv(r"A:\Multi-Touch Marketing Attribution\campaigns.csv")
events = pd.read_csv(r"A:\Multi-Touch Marketing Attribution\events.csv")
products = pd.read_csv(r"A:\Multi-Touch Marketing Attribution\products.csv")
transactions = pd.read_csv(r"A:\Multi-Touch Marketing Attribution\transactions.csv")

# %% [markdown]
# # Verify Dataset Loading
#
# Display the first five rows of each dataset.

# %%
print(customers.head())
print(campaigns.head())
print(events.head())
print(products.head())
print(transactions.head())
# Out:
#    customer_id signup_date country  age  gender loyalty_tier  \
# 0            1  2021-04-08      BR   48    Male       Bronze
# 1            2  2023-04-28      IN   36  Female       Silver
# 2            3  2022-12-18      UK   35  Female       Silver
# 3            4  2022-04-26      US   45    Male       Silver
# 4            5  2022-04-20      IN   53    Male       Silver
#
#   acquisition_channel
# 0            Referral
# 1             Organic
# 2             Organic
# 3         Paid Search
# 4             Organic
#    campaign_id      channel     objective  start_date    end_date  \
# 0            1  Paid Search    Cross-sell  2021-10-25  2021-11-26
# 1            2        Email     Retention  2021-10-24  2021-12-24
# 2            3        Email  Reactivation  2023-10-08  2023-11-30
# 3            4      Display  Reactivation  2022-07-25  2022-10-07
# 4            5       Social   Acquisition  2022-07-09  2022-09-29
#
#   target_segment  expected_uplift
# ...

# %% [markdown]
# # Dataset Dimensions
#
# Check the number of rows and columns in each dataset.

# %%
datasets = {
    "Customers": customers,
    "Campaigns": campaigns,
    "Events": events,
    "Products": products,
    "Transactions": transactions
}

for name, df in datasets.items():
    print(f"{name}: {df.shape}")
# Out:
# Customers: (100000, 7)
# Campaigns: (50, 7)
# Events: (2000000, 12)
# Products: (2000, 6)
# Transactions: (103127, 9)

# %% [markdown]
# # Dataset Information
#
# Inspect the structure and data types of each dataset.

# %%
for name, df in datasets.items():
    print("="*70)
    print(name)
    print("="*70)
    df.info()
# Out:
# ...
# Customers
# ...
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   customer_id          100000 non-null  int64
#  1   signup_date          100000 non-null  str
#  2   country              100000 non-null  str
#  3   age                  100000 non-null  int64
#  4   gender               100000 non-null  str
#  5   loyalty_tier         100000 non-null  str
#  6   acquisition_channel  100000 non-null  str
# dtypes: int64(2), str(5)
# memory usage: 5.3 MB
# ...
# Campaigns
# ...
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   campaign_id      50 non-null     int64
#  1   channel          50 non-null     str
#  2   objective        50 non-null     str
#  3   start_date       50 non-null     str
# ...

# %% [markdown]
# # Duplicate Records
#
# Check for duplicate rows.

# %%
for name, df in datasets.items():
    print(f"{name}: {df.duplicated().sum()} duplicate rows")
# Out:
# Customers: 0 duplicate rows
# Campaigns: 0 duplicate rows
# Events: 0 duplicate rows
# Products: 0 duplicate rows
# Transactions: 0 duplicate rows

# %% [markdown]
# # Summary Statistics
#
# Generate descriptive statistics for numerical and categorical columns.

# %%
for name, df in datasets.items():
    print("\n", "="*70)
    print(name)
    display(df.describe(include="all"))
# Out:
# ...
# Customers
#         customer_id signup_date country           age  gender loyalty_tier  \
# count     100000.00      100000  100000  100000.00000  100000       100000
# unique          NaN        1095       7           NaN       3            4
# top             NaN  2022-11-04      US           NaN    Male       Bronze
# freq            NaN         124   34931           NaN   48054        60276
# mean       50000.50         NaN     NaN      35.22437     NaN          NaN
# ...             ...         ...     ...           ...     ...          ...
# min            1.00         NaN     NaN      18.00000     NaN          NaN
# 25%        25000.75         NaN     NaN      28.00000     NaN          NaN
# 50%        50000.50         NaN     NaN      35.00000     NaN          NaN
# 75%        75000.25         NaN     NaN      42.00000     NaN          NaN
# max       100000.00         NaN     NaN      70.00000     NaN          NaN
#
#        acquisition_channel
# count               100000
# ...

# %% [markdown]
# # Dataset Column Names
#
# List all columns in each dataset.

# %%
for name, df in datasets.items():
    print(f"\n{name}")
    print(df.columns.tolist())
# Out:
# Customers
# ['customer_id', 'signup_date', 'country', 'age', 'gender', 'loyalty_tier', 'acquisition_channel']
#
# Campaigns
# ['campaign_id', 'channel', 'objective', 'start_date', 'end_date', 'target_segment', 'expected_uplift']
#
# Events
# ['event_id', 'timestamp', 'customer_id', 'session_id', 'event_type', 'product_id', 'device_type', 'traffic_source', 'campaign_id', 'page_category', 'session_duration_sec', 'experiment_group']
#
# Products
# ['product_id', 'category', 'brand', 'base_price', 'launch_date', 'is_premium']
#
# Transactions
# ['transaction_id', 'timestamp', 'customer_id', 'product_id', 'quantity', 'discount_applied', 'gross_revenue', 'campaign_id', 'refund_flag']

# %% [markdown]
# # Dataset Memory Usage
#
# Measure the memory consumed by each dataset.

# %%
for name, df in datasets.items():
    memory = df.memory_usage(deep=True).sum() / (1024**2)
    print(f"{name}: {memory:.2f} MB")
# Out:
# Customers: 31.63 MB
# Campaigns: 0.02 MB
# Events: 837.61 MB
# Products: 0.42 MB
# Transactions: 13.77 MB

# %% [markdown]
# # Day 2 Summary
#
# ## Tasks Completed
#
# - Acquired the CRM conversion datasets.
# - Loaded all five CSV files into Pandas.
# - Verified successful loading by previewing the datasets.
# - Checked the dimensions of each dataset.
#
# The datasets are ready for data preprocessing in the next phase.

# %% [markdown]
# # Week 1 - Day 3
#
# ## CRM Data Cleaning
#
# ### Objective
#
# Clean the CRM conversion data by:
#
# - Identifying duplicate customer IDs
# - Removing duplicate customer records
# - Removing invalid customer records
# - Removing test records
# - Removing invalid transaction records
# - Saving the cleaned CRM datasets

# %%
customers.head()
# Out:
#    customer_id signup_date country  age  gender loyalty_tier  \
# 0            1  2021-04-08      BR   48    Male       Bronze
# 1            2  2023-04-28      IN   36  Female       Silver
# 2            3  2022-12-18      UK   35  Female       Silver
# 3            4  2022-04-26      US   45    Male       Silver
# 4            5  2022-04-20      IN   53    Male       Silver
#
#   acquisition_channel
# 0            Referral
# 1             Organic
# 2             Organic
# 3         Paid Search
# 4             Organic

# %%
transactions.head()
# Out:
#    transaction_id            timestamp  customer_id  product_id  quantity  \
# 0               1  2021-12-27 08:25:15        59540      1630.0         3
# 1               2  2023-06-06 21:14:26        54871      1901.0         3
# 2               3  2023-08-31 05:29:54        51818      1884.0         1
# 3               4  2022-06-26 20:33:46        18164      1114.0         2
# 4               5  2023-07-26 18:12:35        86915       408.0         1
#
#    discount_applied  gross_revenue  campaign_id  refund_flag
# 0              0.00          43.74            0            0
# 1              0.00         174.78           21            0
# 2              0.00          40.61           37            0
# 3              0.15          68.76           13            0
# 4              0.00          14.64            4            0

# %% [markdown]
# ## Check Dataset Size
#
# Check the number of customer and transaction records before cleaning.

# %%
print("Customers dataset:", customers.shape)

print("Transactions dataset:", transactions.shape)
# Out:
# Customers dataset: (100000, 7)
# Transactions dataset: (103127, 9)

# %% [markdown]
# ## Identify Duplicate Customer IDs
#
# The `customer_id` column should contain a unique identifier for every customer. Duplicate customer IDs are identified before removing them.

# %%
duplicate_customers = customers.duplicated(
    subset="customer_id"
).sum()

print(
    "Duplicate customer IDs:",
    duplicate_customers
)
# Out:
# Duplicate customer IDs: 0

# %%
customers_clean = customers.drop_duplicates(
    subset="customer_id",
    keep="first"
).copy()

print(
    "Customer records after deduplication:",
    customers_clean.shape
)
# Out:
# Customer records after deduplication: (100000, 7)

# %% [markdown]
# ## Remove Invalid Customer Records
#
# Customer records with missing customer IDs or invalid demographic values are removed.

# %%
customers_clean = customers_clean.dropna(
    subset=["customer_id"]
)

customers_clean = customers_clean[
    customers_clean["age"].between(
        18,
        100
    )
]

# %% [markdown]
# ## Remove Test Customer Records
#
# Test records are identified using customer IDs containing values such as `test`, `dummy`, or `sample`.

# %%
test_pattern = "test|dummy|sample"

test_customers = customers_clean[
    customers_clean["customer_id"]
    .astype(str)
    .str.contains(
        test_pattern,
        case=False,
        na=False
    )
]

print(
    "Test customer records:",
    len(test_customers)
)
# Out:
# Test customer records: 0

# %%
customers_clean = customers_clean[
    ~customers_clean["customer_id"]
    .astype(str)
    .str.contains(
        test_pattern,
        case=False,
        na=False
    )
]

# %% [markdown]
# ## Clean Transaction Records
#
# Remove:
#
# - Duplicate transaction IDs
# - Missing transaction IDs
# - Missing customer IDs
# - Invalid quantities
# - Negative revenue values

# %%
transactions_clean = (
    transactions
    .drop_duplicates(
        subset="transaction_id",
        keep="first"
    )
    .dropna(
        subset=[
            "transaction_id",
            "customer_id"
        ]
    )
    .copy()
)

# %%
transactions_clean = transactions_clean[
    (transactions_clean["quantity"] > 0)
    &
    (transactions_clean["gross_revenue"] >= 0)
]

# %%
valid_customer_ids = set(
    customers_clean["customer_id"]
)

transactions_clean = transactions_clean[
    transactions_clean["customer_id"]
    .isin(valid_customer_ids)
]

# %% [markdown]
# ## Validate Cleaned CRM Data
#
# Verify that duplicate customer IDs and invalid records have been removed successfully.

# %%
print(
    "Duplicate customer IDs:",
    customers_clean
    .duplicated(
        subset="customer_id"
    )
    .sum()
)

print(
    "Duplicate transaction IDs:",
    transactions_clean
    .duplicated(
        subset="transaction_id"
    )
    .sum()
)

print(
    "Missing customer IDs:",
    customers_clean["customer_id"]
    .isnull()
    .sum()
)

print(
    "Missing transaction IDs:",
    transactions_clean["transaction_id"]
    .isnull()
    .sum()
)
# Out:
# Duplicate customer IDs: 0
# Duplicate transaction IDs: 0
# Missing customer IDs: 0
# Missing transaction IDs: 0

# %%
print("CRM Cleaning Summary")

print(
    "Customers before:",
    len(customers)
)

print(
    "Customers after:",
    len(customers_clean)
)

print(
    "Transactions before:",
    len(transactions)
)

print(
    "Transactions after:",
    len(transactions_clean)
)
# Out:
# CRM Cleaning Summary
# Customers before: 100000
# Customers after: 100000
# Transactions before: 103127
# Transactions after: 89974

# %% [markdown]
# ## Save Cleaned CRM Data
#
# The cleaned customer and transaction datasets are saved for future EDA, SQL analysis, and attribution modeling.

# %%
customers_clean.to_csv(
    "../customers_clean.csv",
    index=False
)

transactions_clean.to_csv(
    "../transactions_clean.csv",
    index=False
)

print(
    "Cleaned CRM datasets saved successfully."
)
# Out:
# Cleaned CRM datasets saved successfully.

# %% [markdown]
# # Day 3 Summary
#
# ## Tasks Completed
#
# - Checked duplicate customer IDs
# - Removed duplicate customer records
# - Removed invalid customer records
# - Checked and removed test records
# - Removed duplicate transactions
# - Removed invalid purchase records
# - Validated customer IDs across CRM datasets
# - Saved the cleaned CRM datasets
#
# The cleaned CRM conversion data is ready for exploratory data analysis on Day 4.

# %% [markdown]
# # Week 1 - Day 4
#
# ## Exploratory Data Analysis on CRM Conversions
#
# ### Objective
#
# Perform exploratory data analysis on CRM conversion data to understand:
#
# - Conversion volume
# - Conversion timing
# - Conversion value
#
# The analysis uses the cleaned customer and transaction datasets created on Day 3.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
customers_clean = pd.read_csv(r"A:\Multi-Touch Marketing Attribution\customers_clean.csv"
)

transactions_clean = pd.read_csv(r"A:\Multi-Touch Marketing Attribution\transactions_clean.csv"
)

# %%
transactions_clean["timestamp"] = pd.to_datetime(
    transactions_clean["timestamp"]
)

# %% [markdown]
# ## 1. Conversion Volume Analysis
#
# Analyze the total number of purchase transactions and how conversion volume changes over time.

# %%
total_conversions = len(transactions_clean)

print("Total Conversions:", total_conversions)
# Out:
# Total Conversions: 89974

# %%
daily_conversions = (
    transactions_clean
    .groupby(
        transactions_clean["timestamp"].dt.date
    )
    .size()
)

daily_conversions.head()
# Out:
# timestamp
# 2021-01-01    74
# 2021-01-02    86
# 2021-01-03    85
# 2021-01-04    72
# 2021-01-05    77
# dtype: int64

# %%
plt.figure(figsize=(12, 5))

daily_conversions.plot()

plt.title("Daily CRM Conversion Volume")
plt.xlabel("Date")
plt.ylabel("Number of Conversions")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
#
# The daily conversion trend shows how purchase activity changes over time. Peaks indicate periods of higher customer conversion activity, while lower points represent periods with fewer purchases.

# %% [markdown]
# ## 2. Conversion Timing Analysis
#
# Analyze when customers are most likely to complete purchases by examining conversion activity by hour of the day.

# %%
transactions_clean["conversion_hour"] = (
    transactions_clean["timestamp"].dt.hour
)

# %%
hourly_conversions = (
    transactions_clean
    .groupby("conversion_hour")
    .size()
)

hourly_conversions
# Out:
# conversion_hour
# 0     2405
# 1     1636
# 2     1654
# 3     1608
# 4     2467
#       ...
# 19    5734
# 20    4998
# 21    4134
# 22    3336
# 23    2418
# Length: 24, dtype: int64

# %%
plt.figure(figsize=(10, 5))

hourly_conversions.plot(kind="bar")

plt.title("Conversions by Hour of Day")
plt.xlabel("Hour of Day")
plt.ylabel("Number of Conversions")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
peak_hour = hourly_conversions.idxmax()
peak_conversions = hourly_conversions.max()

print("Peak Conversion Hour:", peak_hour)
print("Conversions During Peak Hour:", peak_conversions)
# Out:
# Peak Conversion Hour: 19
# Conversions During Peak Hour: 5734

# %% [markdown]
# ### Observation
#
# The hourly conversion analysis helps identify the time of day with the highest purchase activity. This information can support campaign scheduling and marketing decisions.

# %% [markdown]
# ## 3. Conversion Value Analysis
#
# Analyze the monetary value generated by customer purchases using the `gross_revenue` column.

# %%
total_revenue = transactions_clean["gross_revenue"].sum()

average_conversion_value = (
    transactions_clean["gross_revenue"].mean()
)

median_conversion_value = (
    transactions_clean["gross_revenue"].median()
)

print(f"Total Revenue: ${total_revenue:,.2f}")
print(
    f"Average Conversion Value: "
    f"${average_conversion_value:,.2f}"
)
print(
    f"Median Conversion Value: "
    f"${median_conversion_value:,.2f}"
)
# Out:
# Total Revenue: $8,630,269.31
# Average Conversion Value: $95.92
# Median Conversion Value: $70.20

# %%
plt.figure(figsize=(10, 5))

plt.hist(
    transactions_clean["gross_revenue"],
    bins=30,
    edgecolor="black"
)

plt.title("Distribution of Conversion Value")
plt.xlabel("Gross Revenue")
plt.ylabel("Number of Transactions")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
#
# The conversion value distribution shows the frequency of low-value and high-value transactions. Comparing the average and median conversion values helps identify whether unusually large purchases influence the overall revenue distribution.

# %% [markdown]
# ## 4. Revenue Trend Over Time
#
# Analyze daily revenue to understand how the monetary value of CRM conversions changes over time.

# %%
daily_revenue = (
    transactions_clean
    .groupby(
        transactions_clean["timestamp"].dt.date
    )["gross_revenue"]
    .sum()
)

# %% [markdown]
# # Day 4 Summary
#
# ## Key Findings
#
# - Total conversions analyzed: **[Your result]**
# - Total gross revenue: **$[Your result]**
# - Average conversion value: **$[Your result]**
# - Median conversion value: **$[Your result]**
# - Peak conversion hour: **[Your result]**
#
# ## Tasks Completed
#
# - Analyzed CRM conversion volume.
# - Examined daily conversion trends.
# - Analyzed conversion timing by hour.
# - Calculated total, average, and median conversion value.
# - Visualized the distribution of transaction values.
# - Analyzed daily revenue trends.
#
# The CRM conversion EDA is complete and the data is ready for validation against Web Analytics data on Day 5.

# %% [markdown]
# # Week 1 - Day 5
#
# ## CRM and Web Analytics Validation
#
# ### Objective
#
# Validate the cleaned CRM conversion data against Web Analytics data by matching customer IDs across:
#
# - Customer records
# - Transaction records
# - Web Analytics events
#
# This ensures that CRM customers and conversions can be connected to their corresponding web interactions.

# %%
print("Total Customers:", len(customers_clean))
print("Total Transactions:", len(transactions_clean))
print("Total Web Events:", len(events))
# Out:
# Total Customers: 100000
# Total Transactions: 89974
# Total Web Events: 2000000

# %% [markdown]
# ## 1. Validate Customer IDs Between CRM and Web Analytics
#
# Extract unique customer IDs from both datasets and identify how many CRM customers are present in the Web Analytics data.

# %%
crm_customer_ids = set(
    customers_clean["customer_id"].dropna().unique()
)

web_customer_ids = set(
    events["customer_id"].dropna().unique()
)

# %%
matched_customer_ids = (
    crm_customer_ids.intersection(web_customer_ids)
)

crm_only_ids = (
    crm_customer_ids.difference(web_customer_ids)
)

web_only_ids = (
    web_customer_ids.difference(crm_customer_ids)
)

# %%
print("Unique CRM Customers:", len(crm_customer_ids))
print("Unique Web Customers:", len(web_customer_ids))

print(
    "Matched Customer IDs:",
    len(matched_customer_ids)
)

print(
    "CRM Customers Not Found in Web Analytics:",
    len(crm_only_ids)
)

print(
    "Web Customers Not Found in CRM:",
    len(web_only_ids)
)
# Out:
# Unique CRM Customers: 100000
# Unique Web Customers: 100000
# Matched Customer IDs: 100000
# CRM Customers Not Found in Web Analytics: 0
# Web Customers Not Found in CRM: 0

# %%
match_percentage = (
    len(matched_customer_ids)
    / len(crm_customer_ids)
    * 100
)

print(
    f"CRM to Web Analytics Match Rate: "
    f"{match_percentage:.2f}%"
)
# Out:
# CRM to Web Analytics Match Rate: 100.00%

# %% [markdown]
# ## 2. Validate Transaction Customers Against Web Analytics
#
# Check whether customers who completed purchases also have corresponding Web Analytics activity.

# %%
transaction_customer_ids = set(
    transactions_clean["customer_id"]
    .dropna()
    .unique()
)

# %%
matched_transaction_customers = (
    transaction_customer_ids
    .intersection(web_customer_ids)
)

unmatched_transaction_customers = (
    transaction_customer_ids
    .difference(web_customer_ids)
)

# %%
print(
    "Unique Customers with Transactions:",
    len(transaction_customer_ids)
)

print(
    "Transaction Customers Found in Web Analytics:",
    len(matched_transaction_customers)
)

print(
    "Transaction Customers Not Found in Web Analytics:",
    len(unmatched_transaction_customers)
)
# Out:
# Unique Customers with Transactions: 58987
# Transaction Customers Found in Web Analytics: 58987
# Transaction Customers Not Found in Web Analytics: 0

# %%
transaction_match_rate = (
    len(matched_transaction_customers)
    / len(transaction_customer_ids)
    * 100
)

print(
    f"Transaction Customer Match Rate: "
    f"{transaction_match_rate:.2f}%"
)
# Out:
# Transaction Customer Match Rate: 100.00%

# %% [markdown]
# ## 3. Validate Individual Transactions Against Web Analytics
#
# Add a validation flag to each transaction indicating whether the customer appears in the Web Analytics dataset.

# %%
transactions_validated = transactions_clean.copy()

transactions_validated["web_analytics_match"] = (
    transactions_validated["customer_id"]
    .isin(web_customer_ids)
)

# %%
transactions_validated[
    "web_analytics_match"
].value_counts()
# Out:
# web_analytics_match
# True    89974
# Name: count, dtype: int64

# %%
unmatched_customers = pd.DataFrame({
    "customer_id": list(
        unmatched_transaction_customers
    )
})

unmatched_customers.head()
# Out:
# Empty DataFrame
# Columns: [customer_id]
# Index: []

# %%
transactions_validated.to_csv(
    "../transactions_validated.csv",
    index=False
)

print(
    "Validated transaction data saved successfully."
)
# Out:
# Validated transaction data saved successfully.

# %% [markdown]
# # Day 5 Summary
#
# ## CRM vs Web Analytics Validation
#
# - Unique CRM customers: **[result]**
# - Unique Web Analytics customers: **[result]**
# - Matched customer IDs: **[result]**
# - CRM-to-Web match rate: **[result]%**
# - Unique transaction customers: **[result]**
# - Transaction customers matched with Web Analytics: **[result]**
# - Transaction customer match rate: **[result]%**
#
# ## Tasks Completed
#
# - Matched CRM customer IDs against Web Analytics customer IDs.
# - Identified matched and unmatched customers.
# - Validated transaction customers against Web Analytics activity.
# - Calculated customer ID match rates.
# - Added a Web Analytics match flag to transaction records.
# - Saved the validated transaction dataset.
#
# ### Outcome
#
# CRM conversion data has been successfully validated against Web Analytics data and is ready for further attribution analysis.

# %% [markdown]
# # Week 1 - Day 6
#
# ## Peer Review and CRM Script Validation
#
# ### Objective
#
# Peer-review Member A and Member B's data cleaning notebooks and verify the quality of the CRM cleaning script.
#
# ### Peer Review Checklist
#
# #### Member A - Ad Spend Data
# - Checked missing values handling.
# - Checked UTM parameter cleaning.
# - Checked campaign ID consistency.
# - Verified that important records were not unnecessarily removed.
#
# #### Member B - Web Analytics Data
# - Checked timestamp standardization.
# - Checked missing value handling.
# - Checked event and session data consistency.
# - Verified that important Web Analytics records were preserved.
#
# #### Member C - CRM Data
# - Rechecked duplicate customer IDs.
# - Rechecked invalid and test records.
# - Verified transaction IDs.
# - Verified customer-to-transaction relationships.
# - Confirmed cleaned output files are valid.
#
# ### Outcome
#
# The cleaning notebooks were reviewed for consistency and data quality. The CRM cleaning workflow was verified and necessary corrections were applied where required.

# %%
print("CRM Final Validation")
print("-" * 40)

print(
    "Duplicate Customer IDs:",
    customers_clean["customer_id"].duplicated().sum()
)

print(
    "Missing Customer IDs:",
    customers_clean["customer_id"].isnull().sum()
)

print(
    "Duplicate Transaction IDs:",
    transactions_clean["transaction_id"].duplicated().sum()
)

print(
    "Missing Transaction IDs:",
    transactions_clean["transaction_id"].isnull().sum()
)

invalid_customer_links = (
    ~transactions_clean["customer_id"]
    .isin(customers_clean["customer_id"])
).sum()

print(
    "Transactions with Invalid Customer IDs:",
    invalid_customer_links
)
# Out:
# CRM Final Validation
# ----------------------------------------
# Duplicate Customer IDs: 0
# Missing Customer IDs: 0
# Duplicate Transaction IDs: 0
# Missing Transaction IDs: 0
# Transactions with Invalid Customer IDs: 0

# %% [markdown]
# # Week 1 - Day 7
#
# ## CRM Notebook Finalization
#
# ### Objective
#
# Finalize the CRM analysis notebook and complete all Week 1 documentation and GitHub tasks.
#
# ### Tasks Completed
#
# - Reviewed all CRM data acquisition steps.
# - Finalized CRM data cleaning.
# - Verified EDA charts and observations.
# - Completed CRM and Web Analytics validation.
# - Cleared notebook cell outputs before commit.
# - Updated the project README.
# - Closed completed Week 1 GitHub Issues.
#
# ### Week 1 Outcome
#
# The CRM conversion dataset was successfully acquired, cleaned, explored, and validated against Web Analytics data. The CRM data is now ready for SQL-based attribution analysis in Week 2.
